# %%
import pandas as pd
import numpy as np
import re

# %%
df2 = pd.read_csv('../scraping_data/df_images.csv')
#df2

# %%
df2
# Out:
#      Unnamed: 0                                        image_links
# 0             0  https://motos-b60.kxcdn.com/sites/default/file...
# 1             1  https://motos-b60.kxcdn.com/sites/default/file...
# 2             2  https://motos-b60.kxcdn.com/sites/default/file...
# 3             3  https://motos-b60.kxcdn.com/sites/default/file...
# 4             4  https://motos-b60.kxcdn.com/sites/default/file...
# ..          ...                                                ...
# 713         713  https://motos-b60.kxcdn.com/sites/default/file...
# 714         714  https://motos-b60.kxcdn.com/sites/default/file...
# 715         715  https://motos-b60.kxcdn.com/sites/default/file...
# 716         716  https://motos-b60.kxcdn.com/sites/default/file...
# 717         717  https://motos-b60.kxcdn.com/sites/default/file...
#
# [718 rows x 2 columns]

# %%
modelos_a_eliminar = ['Aprilia SX 125', 'Aprilia RX 125', 'Aprilia SX 50 Factory', 'Aprilia RX 50 Factory', 'Aprilia SR 50 Motard', 'Aprilia SR 50 R', 'Aprilia Tuono 125', 'Aprilia Shiver 900', 'Aprilia RS4 50', 'Aprilia RS 125', 'Aprilia RS 50', 'Aprilia RX 50', 'Aprilia SR 50 R', 'Aprilia SR Motard 50', 'Aprilia SX 50', 'BMW CE 04 A1', 'BMW CE 04 A2', 'BMW C Evolution', 'Ducati 1200 Multistrada Enduro', 'Ducati 1299 Panigale S', 'Honda CRF 450 L', 'Honda CRF 450RX', 'Honda CRF 450R', 'Honda CRF 250RX', 'Honda CRF 250R', 'Yamaha Neo', 'Yamaha WR 450F', 'Yamaha YZF-R6']

df2 = df2[~df2['image_links'].str.contains('|'.join(modelos_a_eliminar))]

# %%
df2
# Out:
#      Unnamed: 0                                        image_links
# 0             0  https://motos-b60.kxcdn.com/sites/default/file...
# 1             1  https://motos-b60.kxcdn.com/sites/default/file...
# 2             2  https://motos-b60.kxcdn.com/sites/default/file...
# 3             3  https://motos-b60.kxcdn.com/sites/default/file...
# 4             4  https://motos-b60.kxcdn.com/sites/default/file...
# ..          ...                                                ...
# 713         713  https://motos-b60.kxcdn.com/sites/default/file...
# 714         714  https://motos-b60.kxcdn.com/sites/default/file...
# 715         715  https://motos-b60.kxcdn.com/sites/default/file...
# 716         716  https://motos-b60.kxcdn.com/sites/default/file...
# 717         717  https://motos-b60.kxcdn.com/sites/default/file...
#
# [718 rows x 2 columns]

# %%
import re
modelos_regex = '|'.join([re.escape(modelo) for modelo in modelos_a_eliminar])
df2 = df2[~df2['image_links'].str.contains(modelos_regex)]

# %%
df2
# Out:
#      Unnamed: 0                                        image_links
# 0             0  https://motos-b60.kxcdn.com/sites/default/file...
# 1             1  https://motos-b60.kxcdn.com/sites/default/file...
# 2             2  https://motos-b60.kxcdn.com/sites/default/file...
# 3             3  https://motos-b60.kxcdn.com/sites/default/file...
# 4             4  https://motos-b60.kxcdn.com/sites/default/file...
# ..          ...                                                ...
# 713         713  https://motos-b60.kxcdn.com/sites/default/file...
# 714         714  https://motos-b60.kxcdn.com/sites/default/file...
# 715         715  https://motos-b60.kxcdn.com/sites/default/file...
# 716         716  https://motos-b60.kxcdn.com/sites/default/file...
# 717         717  https://motos-b60.kxcdn.com/sites/default/file...
#
# [718 rows x 2 columns]

# %%
import re
modelos_regex = '|'.join([re.escape(modelo) for modelo in modelos_a_eliminar])
df2 = df2[~df2['image_links'].str.contains(modelos_regex)]

# %%
import re
modelos_regex = '|'.join([re.escape(modelo) for modelo in modelos_a_eliminar])
df2 = df2[~df2['image_links'].str.contains(modelos_regex)]

# %%
df2
# Out:
#      Unnamed: 0                                        image_links
# 0             0  https://motos-b60.kxcdn.com/sites/default/file...
# 1             1  https://motos-b60.kxcdn.com/sites/default/file...
# 2             2  https://motos-b60.kxcdn.com/sites/default/file...
# 3             3  https://motos-b60.kxcdn.com/sites/default/file...
# 4             4  https://motos-b60.kxcdn.com/sites/default/file...
# ..          ...                                                ...
# 713         713  https://motos-b60.kxcdn.com/sites/default/file...
# 714         714  https://motos-b60.kxcdn.com/sites/default/file...
# 715         715  https://motos-b60.kxcdn.com/sites/default/file...
# 716         716  https://motos-b60.kxcdn.com/sites/default/file...
# 717         717  https://motos-b60.kxcdn.com/sites/default/file...
#
# [718 rows x 2 columns]

# %%
modelos_a_eliminar = ['Aprilia SX 125', 'Aprilia RX 125', 'Aprilia SX 50 Factory', 'Aprilia RX 50 Factory', 'Aprilia SR 50 Motard', 'Aprilia SR 50 R', 'Aprilia Tuono 125', 'Aprilia Shiver 900', 'Aprilia RS4 50', 'Aprilia RS 125', 'Aprilia RS 50', 'Aprilia RX 50', 'Aprilia SR 50 R', 'Aprilia SR Motard 50', 'Aprilia SX 50', 'BMW CE 04 A1', 'BMW CE 04 A2', 'BMW C Evolution', 'Ducati 1200 Multistrada Enduro', 'Ducati 1299 Panigale S', 'Honda CRF 450 L', 'Honda CRF 450RX', 'Honda CRF 450R', 'Honda CRF 250RX', 'Honda CRF 250R', 'Yamaha Neo', 'Yamaha WR 450F', 'Yamaha YZF-R6']
modelos_regex = '|'.join([re.escape(modelo) for modelo in modelos_a_eliminar])
df2 = df2[~df2['image_links'].str.contains(modelos_regex, flags=re.IGNORECASE, regex=True)]

# %%
df2
# Out:
#      Unnamed: 0                                        image_links
# 0             0  https://motos-b60.kxcdn.com/sites/default/file...
# 1             1  https://motos-b60.kxcdn.com/sites/default/file...
# 2             2  https://motos-b60.kxcdn.com/sites/default/file...
# 3             3  https://motos-b60.kxcdn.com/sites/default/file...
# 4             4  https://motos-b60.kxcdn.com/sites/default/file...
# ..          ...                                                ...
# 713         713  https://motos-b60.kxcdn.com/sites/default/file...
# 714         714  https://motos-b60.kxcdn.com/sites/default/file...
# 715         715  https://motos-b60.kxcdn.com/sites/default/file...
# 716         716  https://motos-b60.kxcdn.com/sites/default/file...
# 717         717  https://motos-b60.kxcdn.com/sites/default/file...
#
# [718 rows x 2 columns]

# %%
modelo_a_eliminar = 'Aprilia SR GT 125'
df2 = df2[~df2['image_links'].str.contains(modelo_a_eliminar, flags=re.IGNORECASE)]

# %%
df2
# Out:
#      Unnamed: 0                                        image_links
# 0             0  https://motos-b60.kxcdn.com/sites/default/file...
# 1             1  https://motos-b60.kxcdn.com/sites/default/file...
# 2             2  https://motos-b60.kxcdn.com/sites/default/file...
# 3             3  https://motos-b60.kxcdn.com/sites/default/file...
# 4             4  https://motos-b60.kxcdn.com/sites/default/file...
# ..          ...                                                ...
# 713         713  https://motos-b60.kxcdn.com/sites/default/file...
# 714         714  https://motos-b60.kxcdn.com/sites/default/file...
# 715         715  https://motos-b60.kxcdn.com/sites/default/file...
# 716         716  https://motos-b60.kxcdn.com/sites/default/file...
# 717         717  https://motos-b60.kxcdn.com/sites/default/file...
#
# [718 rows x 2 columns]

# %%
modelos_a_eliminar = ['Aprilia SX 125', 'Aprilia RX 125', 'Aprilia SX 50 Factory', 'Aprilia RX 50 Factory', 'Aprilia SR 50 Motard', 'Aprilia SR 50 R', 'Aprilia Tuono 125', 'Aprilia Shiver 900', 'Aprilia RS4 50', 'Aprilia RS 125', 'Aprilia RS 50', 'Aprilia RX 50', 'Aprilia SR 50 R', 'Aprilia SR Motard 50', 'Aprilia SX 50', 'BMW CE 04 A1', 'BMW CE 04 A2', 'BMW C Evolution', 'Ducati 1200 Multistrada Enduro', 'Ducati 1299 Panigale S', 'Honda CRF 450 L', 'Honda CRF 450RX', 'Honda CRF 450R', 'Honda CRF 250RX', 'Honda CRF 250R', 'Yamaha Neo', 'Yamaha WR 450F', 'Yamaha YZF-R6']

modelos_regex = '|'.join([re.escape(modelo.lower().replace(' ', '-')) for modelo in modelos_a_eliminar])
df2 = df2[~df2['image_links'].str.contains(modelos_regex, flags=re.IGNORECASE, regex=True)]

# %%
modelos_regex
# Out:
# 'aprilia\\-sx\\-125|aprilia\\-rx\\-125|aprilia\\-sx\\-50\\-factory|aprilia\\-rx\\-50\\-factory|aprilia\\-sr\\-50\\-motard|aprilia\\-sr\\-50\\-r|aprilia\\-tuono\\-125|aprilia\\-shiver\\-900|aprilia\\-rs4\\-50|aprilia\\-rs\\-125|aprilia\\-rs\\-50|aprilia\\-rx\\-50|aprilia\\-sr\\-50\\-r|aprilia\\-sr\\-motard\\-50|aprilia\\-sx\\-50|bmw\\-ce\\-04\\-a1|bmw\\-ce\\-04\\-a2|bmw\\-c\\-evolution|ducati\\-1200\\-multistrada\\-enduro|ducati\\-1299\\-panigale\\-s|honda\\-crf\\-450\\-l|honda\\-crf\\-450rx|honda\\-crf\\-450r|honda\\-crf\\-250rx|honda\\-crf\\-250r|yamaha\\-neo|yamaha\\-wr\\-450f|yamaha\\-yzf\\-r6'

# %%
modelos_a_eliminar = [modelo.lower().replace(" ", "-") for modelo in modelos_a_eliminar]

# %%
modelos_a_eliminar
# Out:
# ['aprilia-sx-125',
#  'aprilia-rx-125',
#  'aprilia-sx-50-factory',
#  'aprilia-rx-50-factory',
#  'aprilia-sr-50-motard',
#  'aprilia-sr-50-r',
#  'aprilia-tuono-125',
#  'aprilia-shiver-900',
#  'aprilia-rs4-50',
#  'aprilia-rs-125',
#  'aprilia-rs-50',
#  'aprilia-rx-50',
#  'aprilia-sr-50-r',
#  'aprilia-sr-motard-50',
#  'aprilia-sx-50',
#  'bmw-ce-04-a1',
#  'bmw-ce-04-a2',
#  'bmw-c-evolution',
#  'ducati-1200-multistrada-enduro',
#  'ducati-1299-panigale-s',
#  'honda-crf-450-l',
#  'honda-crf-450rx',
#  'honda-crf-450r',
#  'honda-crf-250rx',
#  'honda-crf-250r',
#  'yamaha-neo',
#  'yamaha-wr-450f',
#  'yamaha-yzf-r6']
